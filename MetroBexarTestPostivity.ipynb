# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

# %%
metro_pd = pd.read_csv('../CoVID-19_Dashboard_Data.csv')

# %%
type(metro_pd.Date[0])
# Out:
# str

# %%
metro_pd.Date = pd.to_datetime(metro_pd.Date)

# %%
type(metro_pd.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
a = metro_pd.set_index('Date')

# %%
a
# Out:
#                      ObjectId  ReportedOn  ReportedCum  Deceased  Recovered  \
# Date
# 2020-02-12 06:00:00         1         NaN          NaN       NaN        NaN
# 2020-02-13 06:00:00         2         NaN          NaN       NaN        NaN
# 2020-02-14 06:00:00         3         NaN          NaN       NaN        NaN
# 2020-02-15 06:00:00         4         NaN          NaN       NaN        NaN
# 2020-02-16 06:00:00         5         NaN          NaN       NaN        NaN
# ...                       ...         ...          ...       ...        ...
# NaT                       138         NaN          NaN       NaN        NaN
# NaT                       139         NaN          NaN       NaN        NaN
# NaT                       140         NaN          NaN       NaN        NaN
# NaT                       141         NaN          NaN       NaN        NaN
# NaT                       142         NaN          NaN       NaN        NaN
#
#                      Hospitalized  ICU  Vent  StillIll  PosPatients  ...  \
# Date                                                                 ...
# 2020-02-12 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-13 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-14 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-15 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-16 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# ...                           ...  ...   ...       ...          ...  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
#
#                      BCLabTests  BCTestNegative  BCTestPositive  BCTestInc  \
# Date
# 2020-02-12 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-13 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-14 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-15 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-16 06:00:00         NaN             NaN             NaN        NaN
# ...                         ...             ...             ...        ...
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
#
#                      DBCLabTests  DBCTestNegative  DBCTestPositive  \
# Date
# 2020-02-12 06:00:00          NaN              NaN              NaN
# 2020-02-13 06:00:00          NaN              NaN              NaN
# 2020-02-14 06:00:00          NaN              NaN              NaN
# 2020-02-15 06:00:00          NaN              NaN              NaN
# 2020-02-16 06:00:00          NaN              NaN              NaN
# ...                          ...              ...              ...
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
#
#                      DBCTestInc  WeekQuar  EverQuar
# Date
# 2020-02-12 06:00:00         NaN       NaN       NaN
# 2020-02-13 06:00:00         NaN       NaN       NaN
# 2020-02-14 06:00:00         NaN       NaN       NaN
# 2020-02-15 06:00:00         NaN       NaN       NaN
# 2020-02-16 06:00:00         NaN       NaN       NaN
# ...                         ...       ...       ...
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
#
# [142 rows x 28 columns]

# %%
a.T.index
# Out:
# Index(['ObjectId', 'ReportedOn', 'ReportedCum', 'Deceased', 'Recovered',
#        'Hospitalized', 'ICU', 'Vent', 'StillIll', 'PosPatients', 'PUIPatients',
#        'DeathsCum', 'COVIDnICU', 'COVIDonVent', 'TotalVents', 'AvailVent',
#        'TotalStaffedBeds', 'AvailStaffedBeds', 'BCLabTests', 'BCTestNegative',
#        'BCTestPositive', 'BCTestInc', 'DBCLabTests', 'DBCTestNegative',
#        'DBCTestPositive', 'DBCTestInc', 'WeekQuar', 'EverQuar'],
#       dtype='object')

# %%
b = a.loc[a.index.dropna()]

# %%
b
# Out:
#                      ObjectId  ReportedOn  ReportedCum  Deceased  Recovered  \
# Date
# 2020-02-12 06:00:00         1         NaN          NaN       NaN        NaN
# 2020-02-13 06:00:00         2         NaN          NaN       NaN        NaN
# 2020-02-14 06:00:00         3         NaN          NaN       NaN        NaN
# 2020-02-15 06:00:00         4         NaN          NaN       NaN        NaN
# 2020-02-16 06:00:00         5         NaN          NaN       NaN        NaN
# ...                       ...         ...          ...       ...        ...
# 2020-06-16 05:00:00       126       436.0       4876.0       0.0     2343.0
# 2020-06-17 05:00:00       127       269.0       5142.0       1.0     2348.0
# 2020-06-18 05:00:00       128       408.0       5550.0       2.0     2365.0
# 2020-06-19 05:00:00       129       412.0       5962.0       4.0     2481.0
# 2020-06-20 05:00:00       130       382.0       6344.0       0.0     2523.0
#
#                      Hospitalized    ICU  Vent  StillIll  PosPatients  ...  \
# Date                                                                   ...
# 2020-02-12 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-13 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-14 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-15 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-16 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# ...                           ...    ...   ...       ...          ...  ...
# 2020-06-16 05:00:00         518.0  217.0  93.0    2441.0        212.0  ...
# 2020-06-17 05:00:00         525.0  220.0  94.0    2704.0        241.0  ...
# 2020-06-18 05:00:00         544.0  222.0  95.0    3093.0        267.0  ...
# 2020-06-19 05:00:00         563.0  227.0  95.0    3385.0        322.0  ...
# 2020-06-20 05:00:00         575.0  231.0  96.0    3725.0        336.0  ...
#
#                      BCLabTests  BCTestNegative  BCTestPositive  BCTestInc  \
# Date
# 2020-02-12 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-13 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-14 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-15 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-16 06:00:00         NaN             NaN             NaN        NaN
# ...                         ...             ...             ...        ...
# 2020-06-16 05:00:00     94215.0         88414.0          5703.0       98.0
# 2020-06-17 05:00:00     97421.0         91059.0          6264.0       98.0
# 2020-06-18 05:00:00     99544.0         92874.0          6572.0       98.0
# 2020-06-19 05:00:00    104743.0         97079.0          7566.0       98.0
# 2020-06-20 05:00:00    108492.0        100130.0          8264.0       98.0
#
#                      DBCLabTests  DBCTestNegative  DBCTestPositive  \
# Date
# 2020-02-12 06:00:00          NaN              NaN              NaN
# 2020-02-13 06:00:00          NaN              NaN              NaN
# 2020-02-14 06:00:00          NaN              NaN              NaN
# 2020-02-15 06:00:00          NaN              NaN              NaN
# 2020-02-16 06:00:00          NaN              NaN              NaN
# ...                          ...              ...              ...
# 2020-06-16 05:00:00       4017.0           3403.0            613.0
# 2020-06-17 05:00:00       3206.0           2645.0            561.0
# 2020-06-18 05:00:00       2123.0           1815.0            308.0
# 2020-06-19 05:00:00       5199.0           4205.0            994.0
# 2020-06-20 05:00:00       3749.0           3051.0            698.0
#
#                      DBCTestInc  WeekQuar  EverQuar
# Date
# 2020-02-12 06:00:00         NaN       NaN       NaN
# 2020-02-13 06:00:00         NaN       NaN       NaN
# 2020-02-14 06:00:00         NaN       NaN       NaN
# 2020-02-15 06:00:00         NaN       NaN       NaN
# 2020-02-16 06:00:00         NaN       NaN       NaN
# ...                         ...       ...       ...
# 2020-06-16 05:00:00         1.0       NaN       NaN
# 2020-06-17 05:00:00         0.0       NaN       NaN
# 2020-06-18 05:00:00         0.0       NaN       NaN
# 2020-06-19 05:00:00         0.0       NaN       NaN
# 2020-06-20 05:00:00         NaN       NaN       NaN
#
# [130 rows x 28 columns]

# %%
type(metro_pd.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
c = b['DBCTestPositive'].dropna()

# %%
type(c.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(15,8)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('Positive Tests',color='black')
plt.title('Daily Metro Bexar Positive Tests')
plt.bar(c.index,c)
#plt.plot(c)
fig.savefig('MetroDailyPositiveTests.png')

# %%
d = b['DBCLabTests'].dropna()

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(15,8)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('Daily Tests',color='black')
plt.title('Metro Bexar Daily Tests')
plt.bar(d.index,d)
#plt.plot(d)
fig.savefig('MetroDailyTests.png')

# %%
e = pd.concat([c, d], axis=1)

# %%
f = e.loc[e.index.dropna()]

# %%
f.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 72 entries, 2020-04-10 06:00:00 to 2020-06-20 05:00:00
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DBCTestPositive  72 non-null     float64
#  1   DBCLabTests      72 non-null     float64
# dtypes: float64(2)
# memory usage: 1.7 KB

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 72 entries, 2020-04-10 06:00:00 to 2020-06-20 05:00:00
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   DBCTestPositive  72 non-null     float64
#  1   DBCLabTests      72 non-null     float64
# dtypes: float64(2)
# memory usage: 4.2 KB

# %%
f.DBCLabTests
# Out:
# Date
# 2020-04-10 06:00:00     816.0
# 2020-04-11 06:00:00     321.0
# 2020-04-12 06:00:00     315.0
# 2020-04-13 06:00:00    1607.0
# 2020-04-14 06:00:00     508.0
#                         ...
# 2020-06-16 05:00:00    4017.0
# 2020-06-17 05:00:00    3206.0
# 2020-06-18 05:00:00    2123.0
# 2020-06-19 05:00:00    5199.0
# 2020-06-20 05:00:00    3749.0
# Name: DBCLabTests, Length: 72, dtype: float64

# %%
561/3206
# Out:
# 0.17498440424204617

# %%
f['Percentage'] = f['DBCTestPositive'].div(f['DBCLabTests']).mul(100).round()
print (f)
# Out:
#                      DBCTestPositive  DBCLabTests  Percentage
# Date
# 2020-04-10 06:00:00             55.0        816.0         7.0
# 2020-04-11 06:00:00             26.0        321.0         8.0
# 2020-04-12 06:00:00             25.0        315.0         8.0
# 2020-04-13 06:00:00            128.0       1607.0         8.0
# 2020-04-14 06:00:00            -18.0        508.0        -4.0
# ...                              ...          ...         ...
# 2020-06-16 05:00:00            613.0       4017.0        15.0
# 2020-06-17 05:00:00            561.0       3206.0        17.0
# 2020-06-18 05:00:00            308.0       2123.0        15.0
# 2020-06-19 05:00:00            994.0       5199.0        19.0
# 2020-06-20 05:00:00            698.0       3749.0        19.0
#
# [72 rows x 3 columns]

# %%
#months = mdates.MonthLocator()
#days = mdates.DayLocator()
#timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(15,8)
#ax.xaxis.set_major_locator(months)
#ax.xaxis.set_major_formatter(timeFmt)
#ax.xaxis.set_minor_locator(days)
#plt.xlabel('Date',color='black')
#plt.ylabel('Tests',color='black')
#plt.title('Metro Bexar Tests')
ax = plt.subplot(111)
ax.set_title('Bexar Daily Tests Total/Positive')
ax.set_xlabel('Date')
ax.set_ylabel('Test Count')
ax.bar(e.index, e.DBCTestPositive , width=0.8, color='b', align='center')
ax.bar(e.index,e.DBCLabTests, width=0.2, color='g', align='center')
ax.xaxis_date()
ax2 = ax.twinx()  # instantiate a second axes that shares the same x-axis
ax2.set_ylabel('Daily Test Positivity Rate', color='red') 
ax2.set_ylim(-5,100)
ax2.plot(f['Percentage'],'ro--')
ax2.tick_params(axis='y', labelcolor='red')

#fig.tight_layout() 

ax.legend(['Postitve Tests', 'Total Tests'])
ax2.legend(['Positivity Percentage'],loc=1)
#ax.autoscale(tight=True)
#ax.xaxis_date()
#plt.bar(f.index,f)
#plt.plot(f)
fig.savefig('MetroTestsConcat.png')

# %%
for x in e.DBCTestPositive:
    print(x)
# Out:
# 55.0
# 26.0
# 25.0
# 128.0
# -18.0
# 36.0
# 20.0
# 18.0
# 22.0
# 36.0
# 30.0
# 16.0
# 225.0
# 30.0
# 47.0
# 50.0
# 37.0
# 33.0
# 40.0
# 31.0
# 44.0
# 105.0
# 71.0
# 72.0
# 45.0
# 73.0
# 39.0
# 55.0
# 40.0
# 45.0
# 68.0
# 16.0
# 10.0
# 48.0
# 35.0
# 107.0
# 69.0
# 41.0
# 33.0
# 56.0
# 104.0
# 69.0
# 61.0
# 33.0
# 38.0
# 20.0
# 38.0
# 36.0
# 52.0
# 64.0
# 57.0
# 45.0
# 40.0
# 48.0
# 76.0
# 82.0
# 112.0
# 66.0
# 85.0
# 53.0
# 215.0
# 96.0
# 363.0
# 193.0
# 208.0
# 115.0
# 222.0
# 613.0
# 561.0
# 308.0
# 994.0
# 698.0

# %%
for x in f.values:
    print(x, int(x[0]/x[1] *100))
# Out:
# [ 55. 816.   7.] 6
# [ 26. 321.   8.] 8
# [ 25. 315.   8.] 7
# [ 128. 1607.    8.] 7
# [-18. 508.  -4.] -3
# [ 36. 643.   6.] 5
# [ 20. 505.   4.] 3
# [ 18. 362.   5.] 4
# [ 22. 685.   3.] 3
# [ 36. 848.   4.] 4
# [ 30. 815.   4.] 3
# [ 16. 311.   5.] 5
# [ 225. 3324.    7.] 6
# [ 30. 577.   5.] 5
# [ 47. 947.   5.] 4
