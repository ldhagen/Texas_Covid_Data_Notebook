# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
# %matplotlib inline

# %%
df_Texas_Covid_case = pd.read_excel("../Texas COVID-19 Case Count Data by County.xlsx",header=2)

# %%
a = df_Texas_Covid_case.set_index('County Name')

# %%
b = a.T.Travis[a.columns[1:]]

# %%
dated_dict = {}
count = 0
for x in b:
    month_temp = int(b.index[count][-5:].split('-')[0])
    day_temp = int(b.index[count][-5:].split('-')[1])
    dated_dict[datetime.datetime(2020, month_temp, day_temp)] = b[count]
    count += 1

# %%
dated_df = pd.DataFrame(dated_dict.items(), columns=['Date', 'Total Cases'])

# %%
c = dated_df.set_index('Date')

# %%
import datetime
import matplotlib.dates as mdates
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('Total Reported',color='black')
plt.plot(c)
plt.title('Travis County Total COVID19 Cases')
plt.savefig('TravisTotal.png')

# %%
c_5day_moving= c.rolling(5).mean().shift()

# %%
c
# Out:
#             Total Cases
# Date
# 2020-03-04          0.0
# 2020-03-05          0.0
# 2020-03-06          0.0
# 2020-03-09          0.0
# 2020-03-10          0.0
# ...                 ...
# 2020-06-09       3815.0
# 2020-06-10       3976.0
# 2020-06-11       4109.0
# 2020-06-12       4238.0
# 2020-06-13       4314.0
#
# [99 rows x 1 columns]

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('Total Reported',color='black')
plt.plot(c_5day_moving)
plt.title('5 Day Moving Travis County Total COVID19 Cases')
plt.savefig('TravisTotalMoving.png')

# %%
x = c.diff(periods = 1)

# %%
print(x[-5:].to_markdown())
# Out:
# | Date                |   Total Cases |
# |:--------------------|--------------:|
# | 2020-06-09 00:00:00 |           118 |
# | 2020-06-10 00:00:00 |           161 |
# | 2020-06-11 00:00:00 |           133 |
# | 2020-06-12 00:00:00 |           129 |
# | 2020-06-13 00:00:00 |            76 |

# %%
x.rename(columns={'Total Cases':'New Cases'}, inplace=True)

# %%
print(x[-5:].to_markdown())
# Out:
# | Date                |   New Cases |
# |:--------------------|------------:|
# | 2020-06-09 00:00:00 |         118 |
# | 2020-06-10 00:00:00 |         161 |
# | 2020-06-11 00:00:00 |         133 |
# | 2020-06-12 00:00:00 |         129 |
# | 2020-06-13 00:00:00 |          76 |

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(15,4)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('New Cases',color='black')
plt.title('Travis County Daily New Cases')
plt.bar(x.index,x['New Cases'])
fig.savefig('TravisNewCasesDaily.png')

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(20,15)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
#ax.xaxis.set_minor_locator(days)
#plt.subplot(211)
plt.xlabel('Date',color='black')
plt.ylabel('Total Reported',color='black')
plt.plot(c_5day_moving)
plt.title('5 Day Moving Harris County Total COVID19 Cases')
# Out:
# Text(0.5, 1.0, '5 Day Moving Harris County Total COVID19 Cases')
