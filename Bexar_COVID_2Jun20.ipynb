# %%
import pandas as pd

# %%
import numpy as np

# %%
# !ls -alt
# Out:
# total 424
# -rw------- 1 ldhagen ldhagen  11193 Jun  2 17:11  nohup.out
# drwxrwxrwx 1 ldhagen ldhagen   4096 Jun  2 17:10  .
# -rw-rw-rw- 1 ldhagen ldhagen   5198 Jun  2 17:10  Bexar_COVID_2Jun20.ipynb
# -rw-rw-rw- 1 ldhagen ldhagen  16681 Jun  2 16:57  Texas_COVID_2Jun20.ipynb
# -rw-rw-rw- 1 ldhagen ldhagen   4197 Jun  2 16:28  Untitled1.ipynb
# drwxrwxrwx 1 ldhagen ldhagen   4096 Jun  2 16:24  .ipynb_checkpoints
# -rwxrwxrwx 1 ldhagen ldhagen 100046 Jun  2 15:51  Texas_COVID_2Jun20PM.xlsx
# -rw-rw-rw- 1 ldhagen ldhagen   8276 Jun  2 14:01  Texas_COVID_1Jun20-TestNumbers.ipynb
# -rw-rw-rw- 1 ldhagen ldhagen  12567 Jun  2 13:43  Texas_COVID_1Jun20.ipynb
# -rwxrwxrwx 1 ldhagen ldhagen  71515 Jun  2 13:34 'Cumulative Tests over Time by County.xlsx'
# -rw-rw-rw- 1 ldhagen ldhagen     72 Jun  2 13:22  Untitled.ipynb
# drwxrwxrwx 1 ldhagen ldhagen   4096 Jun  2 13:18  .git
# drwxrwxrwx 1 ldhagen ldhagen   4096 Jun  1 16:48  ..
# -rw-rw-rw- 1 ldhagen ldhagen     99 Jun  1 16:47  README.md
# -rwxrwxrwx 1 ldhagen ldhagen 101228 Jun  1 16:12 'Texas COVID-19 Case Count Data by County (1).xlsx'

# %%
df_Texas_Covid = pd.read_excel('Texas_COVID_2Jun20PM.xlsx', header=2)

# %%
c = df_Texas_Covid

# %%
'Bexar' in c['County Name'].values
# Out:
# True

# %%
c['County Name'][14]
# Out:
# 'Bexar'

# %%
type(c[['County Name']])
# Out:
# pandas.core.frame.DataFrame

# %%
c['County Name']
# Out:
# 0                                               Anderson
# 1                                                Andrews
# 2                                               Angelina
# 3                                                Aransas
# 4                                                 Archer
#                              ...
# 260    Population data is based on Texas population p...
# 261    Please also note that total and county-level c...
# 262                       Reporting Methodology Updates:
# 263    On March 24, DSHS updated the method of report...
# 264    The case counts do not include people who were...
# Name: County Name, Length: 265, dtype: object

# %%
c[['County Name']]
# Out:
#                                            County Name
# 0                                             Anderson
# 1                                              Andrews
# 2                                             Angelina
# 3                                              Aransas
# 4                                               Archer
# ..                                                 ...
# 260  Population data is based on Texas population p...
# 261  Please also note that total and county-level c...
# 262                     Reporting Methodology Updates:
# 263  On March 24, DSHS updated the method of report...
# 264  The case counts do not include people who were...
#
# [265 rows x 1 columns]

# %%
c.loc[c['County Name'] == 'Bexar']
# Out:
#    County Name Population  Cases\r\r\r\n\r\r\r\n03-04  \
# 14       Bexar    2093502                         0.0
#
#     Cases\r\r\r\n\r\r\r\n03-05  Cases\r\r\r\n\r\r\r\n03-06  \
# 14                         0.0                         0.0
#
#     Cases\r\r\r\n\r\r\r\n03-09  Cases\r\r\r\n\r\r\r\n03-10  \
# 14                         0.0                         0.0
#
#     Cases\r\r\r\n\r\r\r\n03-11  Cases\r\r\r\n\r\r\r\n03-12  \
# 14                         0.0                         0.0
#
#     Cases\r\r\r\n\r\r\r\n03-13  ...  Cases\r\r\r\n05-24  Cases\r\r\r\n05-25  \
# 14                         0.0  ...              2418.0              2442.0
#
#     Cases\r\r\r\n05-26  Cases\r\r\r\n05-27  Cases\r\r\r\n05-28  \
# 14              2449.0              2480.0              2525.0
#
#     Cases\r\r\r\n05-29  Cases\r\r\r\n05-30  Cases\r\r\r\n05-31  Cases 06-01  \
# 14              2583.0              2636.0              2825.0       2830.0
#
#     Cases 06-02
# 14       2839.0
#
# [1 rows x 90 columns]

# %%
d = c.set_index('County Name')

# %%
d.loc['Bexar']
# Out:
# Population                    2093502
# Cases\r\r\r\n\r\r\r\n03-04          0
# Cases\r\r\r\n\r\r\r\n03-05          0
# Cases\r\r\r\n\r\r\r\n03-06          0
# Cases\r\r\r\n\r\r\r\n03-09          0
#                                ...
# Cases\r\r\r\n05-29               2583
# Cases\r\r\r\n05-30               2636
# Cases\r\r\r\n05-31               2825
# Cases 06-01                      2830
# Cases 06-02                      2839
# Name: Bexar, Length: 89, dtype: object

# %%
d.loc['Bexar'][1:].index[0]
# Out:
# 'Cases\r\r\r\n\r\r\r\n03-04'

# %%
count = 0
current_total = 0
for x in d.loc['Bexar'][1:]:
    print(d.loc['Bexar'][1:].index[count], int(x), int(x - current_total))
    count += 1
    current_total = x
# Out:
# Cases
#
# 03-04 0 0
# Cases
#
# 03-05 0 0
# Cases
#
# 03-06 0 0
# Cases
#
# 03-09 0 0
# Cases
#
# 03-10 0 0
# Cases
#
# 03-11 0 0
# Cases
#
# 03-12 0 0
# Cases
#
# 03-13 0 0
# Cases
#
# 03-15 3 3
# Cases
#
# 03-16 3 0
# Cases
#
# 03-17 3 0
# Cases
#
# 03-18 4 1
# Cases
#
# 03-19 6 2
# Cases
#
# 03-20 12 6
# Cases
#
# 03-21 24 12
# Cases
#
# 03-22 24 0
# Cases
#
# 03-23 24 0
# Cases
#
# 03-24 57 33
# Cases
#
# 03-25 69 12
# Cases
#
# 03-26 84 15
# Cases
#
# 03-27 113 29
# Cases
#
# 03-28 125 12
# Cases
#
# 03-29 140 15
# Cases
#
# 03-30 157 17
# Cases
#
# 03-31 168 11
# Cases
#
# 04-01 207 39
# Cases
#
# 04-02 229 22
# Cases
#
# 04-03 254 25
# Cases
#
# 04-04 342 88
# Cases
#
# 04-05 384 42
# Cases
#
# 04-06 410 26
# Cases
#
# 04-07 456 46
# Cases
#
# 04-08 503 47
# Cases
#
# 04-09 554 51
# Cases
#
# 04-10 615 61
# Cases
#
# 04-11 665 50
# Cases
#
# 04-12 723 58
# Cases
#
# 04-13 772 49
# Cases
#
# 04-14 794 22
# Cases
#
# 04-15 815 21
# Cases
#
# 04-16 890 75
# Cases
#
# 04-17 918 28
# Cases
#
# 04-18 959 41
# Cases
#
# 04-19 992 33
# Cases
#
# 04-20 1015 23
# Cases
#
# 04-21 1029 14
# Cases
#
# 04-22 1080 51
# Cases
#
# 04-23 1126 46
# Cases
#
# 04-24 1167 41
# Cases
#
# 04-25 1195 28
# Cases
#
# 04-26 1231 36
# Cases
#
# 04-27 1254 23
# Cases
#
# 04-28 1275 21
# Cases
#
# 04-29 1307 32
# Cases
# 04-30 1326 19
# Cases
# 05-01 1374 48
# Cases
# 05-02 1477 103
# Cases
# 05-03 1585 108
# Cases
# 05-04 1613 28
# Cases
# 05-05 1652 39
# Cases
# 05-06 1677 25
# Cases
# 05-07 1761 84
# Cases
# 05-08 1805 44
# Cases
# 05-09 1835 30
# Cases
# 05-10 1901 66
# Cases
# 05-11 1901 0
# Cases
# 05-12 1920 19
# Cases
# 05-13 1942 22
# Cases
# 05-14 1976 34
# Cases
# 05-15 2041 65
# Cases
# 05-16 2120 79
# Cases
# 05-17 2120 0
# Cases
# 05-18 2120 0
# Cases
# 05-19 2192 72
# Cases
# 05-20 2278 86
# Cases
# 05-21 2322 44
# Cases
# 05-22 2371 49
# Cases
# 05-23 2392 21
# Cases
# 05-24 2418 26
# Cases
# 05-25 2442 24
# Cases
# 05-26 2449 7
# Cases
# 05-27 2480 31
# Cases
# 05-28 2525 45
# Cases
# 05-29 2583 58
# Cases
# 05-30 2636 53
# Cases
# 05-31 2825 189
# Cases 06-01 2830 5
# Cases 06-02 2839 9

# %%
d.loc['Total'][1:]
# Out:
# Cases\r\r\r\n\r\r\r\n03-04        0
# Cases\r\r\r\n\r\r\r\n03-05        0
# Cases\r\r\r\n\r\r\r\n03-06        5
# Cases\r\r\r\n\r\r\r\n03-09       12
# Cases\r\r\r\n\r\r\r\n03-10       15
#                               ...
# Cases\r\r\r\n05-29            61006
# Cases\r\r\r\n05-30            62338
# Cases\r\r\r\n05-31            64287
# Cases 06-01                   64880
# Cases 06-02                   66568
# Name: Total, Length: 88, dtype: object

# %%
count = 0
current_total = 0
for x in d.loc['Total'][1:]:
    print(d.loc['Total'][1:].index[count], int(x), int(x - current_total))
    count += 1
    current_total = x
# Out:
# Cases
#
# 03-04 0 0
# Cases
#
# 03-05 0 0
# Cases
#
# 03-06 5 5
# Cases
#
# 03-09 12 7
# Cases
#
# 03-10 15 3
# Cases
#
# 03-11 18 3
# Cases
#
