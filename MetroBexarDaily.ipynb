# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import matplotlib.dates as mdates

# %%
metro_pd = pd.read_csv('../CoVID-19_Dashboard_Data.csv')

# %%
type(metro_pd.Date[0])
# Out:
# str

# %%
metro_pd.Date = pd.to_datetime(metro_pd.Date)

# %%
type(metro_pd.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
a = metro_pd.set_index('Date')

# %%
a
# Out:
#                      ObjectId  ReportedOn  ReportedCum  Deceased  Recovered  \
# Date
# 2020-02-12 06:00:00         1         NaN          NaN       NaN        NaN
# 2020-02-13 06:00:00         2         NaN          NaN       NaN        NaN
# 2020-02-14 06:00:00         3         NaN          NaN       NaN        NaN
# 2020-02-15 06:00:00         4         NaN          NaN       NaN        NaN
# 2020-02-16 06:00:00         5         NaN          NaN       NaN        NaN
# ...                       ...         ...          ...       ...        ...
# NaT                       138         NaN          NaN       NaN        NaN
# NaT                       139         NaN          NaN       NaN        NaN
# NaT                       140         NaN          NaN       NaN        NaN
# NaT                       141         NaN          NaN       NaN        NaN
# NaT                       142         NaN          NaN       NaN        NaN
#
#                      Hospitalized  ICU  Vent  StillIll  PosPatients  ...  \
# Date                                                                 ...
# 2020-02-12 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-13 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-14 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-15 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# 2020-02-16 06:00:00           NaN  NaN   NaN       NaN          NaN  ...
# ...                           ...  ...   ...       ...          ...  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
# NaT                           NaN  NaN   NaN       NaN          NaN  ...
#
#                      BCLabTests  BCTestNegative  BCTestPositive  BCTestInc  \
# Date
# 2020-02-12 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-13 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-14 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-15 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-16 06:00:00         NaN             NaN             NaN        NaN
# ...                         ...             ...             ...        ...
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
# NaT                         NaN             NaN             NaN        NaN
#
#                      DBCLabTests  DBCTestNegative  DBCTestPositive  \
# Date
# 2020-02-12 06:00:00          NaN              NaN              NaN
# 2020-02-13 06:00:00          NaN              NaN              NaN
# 2020-02-14 06:00:00          NaN              NaN              NaN
# 2020-02-15 06:00:00          NaN              NaN              NaN
# 2020-02-16 06:00:00          NaN              NaN              NaN
# ...                          ...              ...              ...
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
# NaT                          NaN              NaN              NaN
#
#                      DBCTestInc  WeekQuar  EverQuar
# Date
# 2020-02-12 06:00:00         NaN       NaN       NaN
# 2020-02-13 06:00:00         NaN       NaN       NaN
# 2020-02-14 06:00:00         NaN       NaN       NaN
# 2020-02-15 06:00:00         NaN       NaN       NaN
# 2020-02-16 06:00:00         NaN       NaN       NaN
# ...                         ...       ...       ...
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
# NaT                         NaN       NaN       NaN
#
# [142 rows x 28 columns]

# %%
b = a.loc[a.index.dropna()]

# %%
b
# Out:
#                      ObjectId  ReportedOn  ReportedCum  Deceased  Recovered  \
# Date
# 2020-02-12 06:00:00         1         NaN          NaN       NaN        NaN
# 2020-02-13 06:00:00         2         NaN          NaN       NaN        NaN
# 2020-02-14 06:00:00         3         NaN          NaN       NaN        NaN
# 2020-02-15 06:00:00         4         NaN          NaN       NaN        NaN
# 2020-02-16 06:00:00         5         NaN          NaN       NaN        NaN
# ...                       ...         ...          ...       ...        ...
# 2020-06-12 05:00:00       122       172.0       4012.0       2.0     2271.0
# 2020-06-13 05:00:00       123       230.0       4242.0       4.0     2271.0
# 2020-06-14 05:00:00       124       151.0       4393.0       0.0     2380.0
# 2020-06-15 05:00:00       125        44.0       4437.0       1.0     2287.0
# 2020-06-16 05:00:00       126       436.0       4876.0       0.0     2343.0
#
#                      Hospitalized    ICU  Vent  StillIll  PosPatients  ...  \
# Date                                                                   ...
# 2020-02-12 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-13 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-14 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-15 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# 2020-02-16 06:00:00           NaN    NaN   NaN       NaN          NaN  ...
# ...                           ...    ...   ...       ...          ...  ...
# 2020-06-12 05:00:00         493.0  211.0  91.0    1657.0        138.0  ...
# 2020-06-13 05:00:00         500.0  213.0  92.0    1883.0        148.0  ...
# 2020-06-14 05:00:00         506.0  214.0  92.0    2025.0        176.0  ...
# 2020-06-15 05:00:00         507.0  215.0  92.0    2061.0        187.0  ...
# 2020-06-16 05:00:00         518.0  217.0  93.0    2441.0        212.0  ...
#
#                      BCLabTests  BCTestNegative  BCTestPositive  BCTestInc  \
# Date
# 2020-02-12 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-13 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-14 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-15 06:00:00         NaN             NaN             NaN        NaN
# 2020-02-16 06:00:00         NaN             NaN             NaN        NaN
# ...                         ...             ...             ...        ...
# 2020-06-12 05:00:00     85102.0         80462.0          4545.0       95.0
# 2020-06-13 05:00:00     87113.0         82263.0          4753.0       97.0
# 2020-06-14 05:00:00     88243.0         83278.0          4868.0       97.0
# 2020-06-15 05:00:00     90198.0         85011.0          5090.0       97.0
# 2020-06-16 05:00:00     94215.0         88414.0          5703.0       98.0
#
#                      DBCLabTests  DBCTestNegative  DBCTestPositive  \
# Date
# 2020-02-12 06:00:00          NaN              NaN              NaN
# 2020-02-13 06:00:00          NaN              NaN              NaN
# 2020-02-14 06:00:00          NaN              NaN              NaN
# 2020-02-15 06:00:00          NaN              NaN              NaN
# 2020-02-16 06:00:00          NaN              NaN              NaN
# ...                          ...              ...              ...
# 2020-06-12 05:00:00       1779.0           1586.0            193.0
# 2020-06-13 05:00:00       2011.0           1801.0            208.0
# 2020-06-14 05:00:00       1130.0           1015.0            115.0
# 2020-06-15 05:00:00       1955.0           1733.0            222.0
# 2020-06-16 05:00:00       4017.0           3403.0            613.0
#
#                      DBCTestInc  WeekQuar  EverQuar
# Date
# 2020-02-12 06:00:00         NaN       NaN       NaN
# 2020-02-13 06:00:00         NaN       NaN       NaN
# 2020-02-14 06:00:00         NaN       NaN       NaN
# 2020-02-15 06:00:00         NaN       NaN       NaN
# 2020-02-16 06:00:00         NaN       NaN       NaN
# ...                         ...       ...       ...
# 2020-06-12 05:00:00         0.0       NaN       NaN
# 2020-06-13 05:00:00         2.0       NaN       NaN
# 2020-06-14 05:00:00         0.0       NaN       NaN
# 2020-06-15 05:00:00         0.0       NaN       NaN
# 2020-06-16 05:00:00         1.0       NaN       NaN
#
# [126 rows x 28 columns]

# %%
type(metro_pd.Date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
c = b['ReportedOn'].dropna()

# %%
type(c.index[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
months = mdates.MonthLocator()
days = mdates.DayLocator()
timeFmt = mdates.DateFormatter('%b %Y')
fig, ax = plt.subplots()
fig.set_size_inches(15,8)
ax.xaxis.set_major_locator(months)
ax.xaxis.set_major_formatter(timeFmt)
ax.xaxis.set_minor_locator(days)
plt.xlabel('Date',color='black')
plt.ylabel('Daily Cases',color='black')
plt.title('Metro Bexar County Daily Cases')
plt.bar(c.index,c)
fig.savefig('MetroBexarDaily.png')
